# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print('matplotlib:',mlp.__version__)
# Out:
# matplotlib: 3.1.1

# %%
from numpy.random import rand,randint,uniform,sample

# %%
x=np.arange(40,50)
y=np.arange(50,60)

# %%
plt.plot(x,y,'go--',linewidth=1,markersize=5)
plt.title('Line Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
days = [1,2,3,4,5,6,7] #days of d week
sales_1 = [160,150,140,145,175,165,180] #sales of company1
sales_2 = [70,90,160,150,140,145,175]  #sales of company2

# %%
plt.plot(days,sales_1,'go--',linewidth=1,markersize=5)
plt.plot(days,sales_2,'rd--',linewidth=1,markersize=5)
plt.title('Line Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
x = [1,2,3,4]
y1 = [4,3,2,1]
y2 = [10,20,30,40]
y3 = [40,30,20,10]
y4 = [1,2,1,2]
y5 = [40,70,90,70]

plt.subplot(3,3,1)
plt.plot(x,y1,'r--')
plt.subplot(3,3,2)
plt.plot(x,y2,'g--')
plt.subplot(3,3,3)
plt.plot(x,y3,'b*--')
plt.subplot(3,3,4)
plt.plot(x,y4,'go')
plt.subplot(3,3,5)
plt.plot(x,y5,'bo')
